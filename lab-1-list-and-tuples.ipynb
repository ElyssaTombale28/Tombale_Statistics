# %% [markdown]
# # Lists and Tuples <hr style="border: 2.5px solid #fa6194ff"></hr>

# %% [markdown]
# <b> Elyssa C. Tombale </b>
# <br> T09-A </br>

# %% [markdown]
# Creating List

# %%
number = [1, 2, 3, 4, 5]
number
# Out:
# [1, 2, 3, 4, 5]

# %%
type(number)
# Out:
# list

# %%
fruits = ['apple', 'banana', 'grapes']

# %%
mixed_list = [10, 'hello', 2.5, True]
mixed_list
# Out:
# [10, 'hello', 2.5, True]

# %% [markdown]
# Indexing

# %%
number = [1, 2, 3, 4, 5]

# %%
number[2]
# Out:
# 3

# %%
number[-3]
# Out:
# 3

# %% [markdown]
# # Modifying Elements

# %%
fruits = ['apple', 'banana', 'grapes']

# %%
fruits[0] = 'orange'
fruits
# Out:
# ['orange', 'banana', 'grapes']

# %%
fruits[-2] = 'blueberry'
fruits
# Out:
# ['orange', 'blueberry', 'grapes']

# %% [markdown]
# # Adding Elements

# %%
fruits = ['apple', 'banana', 'grapes']

# %%
fruits.append('orange')
fruits
# Out:
# ['apple', 'banana', 'grapes', 'orange']

# %%
fruits.insert(1, 'blueberry')
fruits
# Out:
# ['apple', 'blueberry', 'banana', 'grapes', 'orange']

# %% [markdown]
# # Removing Elements

# %%
fruits = ['apple', 'banana', 'grapes']
fruits
# Out:
# ['apple', 'banana', 'grapes']

# %%
'banana' in fruits
# Out:
# True

# %%
fruits.remove('banana')

# %%
'banana' in fruits
# Out:
# False

# %%
fruits.pop(0)
# Out:
# 'apple'

# %%
fruits
# Out:
# ['grapes']

# %% [markdown]
# # sort() and sorted()

# %%
numbers = [3, 1, 4, 5, 2]
numbers
# Out:
# [3, 1, 4, 5, 2]

# %%
sorted(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
numbers
# Out:
# [3, 1, 4, 5, 2]

# %%
numbers.sort()

# %%
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
numbers.sort(reverse = True)

# %%
numbers
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# # Slicing

# %%
 numbers = [3, 5, 1, 2, 2, 3, 3, 7, 8 ]
numbers
# Out:
# [3, 5, 1, 2, 2, 3, 3, 7, 8]

# %%
len(numbers)
# Out:
# 9

# %%
sub = numbers[1:5]
sub
# Out:
# [5, 1, 2, 2]

# %%
numbers[0:8:2]
# Out:
# [3, 1, 2, 3]

# %% [markdown]
# # Tuples

# %%
my_tuple = (1,2,3,4,5)
my_tuple
# Out:
# (1, 2, 3, 4, 5)

# %%
type(my_tuple)
# Out:
# tuple

# %%
len(my_tuple)
# Out:
# 5

# %%
my_tuple[1:3]
# Out:
# (2, 3)

# %%
my_tuple[1] = 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 my_tuple[1] = 1
#
# TypeError: 'tuple' object does not support item assignment

# %%
my_tuple = (1, 1, 2, 3, 4, 5)
my_tuple
# Out:
# (1, 1, 2, 3, 4, 5)
