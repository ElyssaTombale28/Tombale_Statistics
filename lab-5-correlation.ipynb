# %% [markdown]
# # CORRELATION <hr style="border: 2.5px solid #fa6194ff"></hr>

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
#load dataset
df = pd.read_csv(r'dataset/current-power.csv', 
                    delimiter=",")
df
# Out:
#    Current  Power
# 0      2.0    100
# 1      3.5    200
# 2      1.8     90
# 3      4.2    210
# 4      2.7    110

# %%
#covariance of the current and power
df.cov()
# Out:
#          Current    Power
# Current    1.023    56.15
# Power     56.150  3370.00

# %%
#scatter plot
x = df['Current']
y = df['Power']

plt.figure()
plt.scatter(x,y)
plt.title('Device Current vs. Power Response')
plt.ylabel('Power (W)')
plt.xlabel('Current (A)')
plt.show()

# %%
# correlation coefficient of current and power
df.corr()
# Out:
#           Current     Power
# Current  1.000000  0.956306
# Power    0.956306  1.000000

# %%
#regression line
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
line = slope * x + intercept

#scatter plot
plt.figure(figsize=(7,4))
plt.scatter(x,y,
            color='#1C1F24',
            alpha=0.6,
            label='Data Points')

#line plot
plt.plot(x, line,
         color='#126782',
         label=f'Regression line (r = {r_value:.3f})')

plt.title('Device Current vs. Power Response')
plt.ylabel('Power (W)')
plt.xlabel('Current (A)')
plt.legend()
plt.show()

# %% [markdown]
# Air Quality

# %%
#Load dataset
air = pd.read_csv(r"dataset\air-quality.csv",
                    delimiter=",")
air
# Out:
#         NOx    NO2  Temperature  Relative_Humidity
# 0      76.0   84.0         36.4               21.0
# 1     135.0   96.0          3.1               48.1
# 2     239.0   81.0         20.2               53.1
# 3     187.0  108.0         30.5               24.2
# 4     412.0   86.0         20.4               71.6
# ...     ...    ...          ...                ...
# 1988  293.0  128.0          5.1               65.5
# 1989  274.0  167.0          4.2               48.7
# 1990   44.0   63.0         11.6               62.2
# 1991  334.0  148.0         19.5               15.3
# 1992  248.0   95.0         21.1               58.3
#
# [1993 rows x 4 columns]

# %%
#covariance of the air
air.cov()
# Out:
#                             NOx          NO2  Temperature  Relative_Humidity
# NOx                28173.084094  5552.796230  -365.527249         606.827211
# NO2                 5552.796230  1908.125712   -66.474749         -78.688877
# Temperature         -365.527249   -66.474749    77.603456         -87.048393
# Relative_Humidity    606.827211   -78.688877   -87.048393         298.924626

# %%
# correlation coefficient of current and power
air.corr()
# Out:
#                         NOx       NO2  Temperature  Relative_Humidity
# NOx                1.000000  0.757340    -0.247208           0.209106
# NO2                0.757340  1.000000    -0.172748          -0.104191
# Temperature       -0.247208 -0.172748     1.000000          -0.571530
# Relative_Humidity  0.209106 -0.104191    -0.571530           1.000000

# %%
#regression line
x = air['NOx']
y = air['Relative_Humidity']
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
line = slope * x + intercept

#scatter plot
plt.figure(figsize=(7,4))
plt.scatter(x,y,
            color="#F546A3",
            alpha=0.6,
            label='Data Points')

#line plot
plt.plot(x, line,
         color="#000000",
         label=f'Regression line (r = {r_value:.3f})')

plt.title('NOx vs. Humidity Correlation')
plt.ylabel('Relative Humidity (%)')
plt.xlabel('NOx (ug/cu.m)')
plt.legend()
plt.show()

# %%
#regression line
x = air['NO2']
y = air['Relative_Humidity']
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
line = slope * x + intercept

#scatter plot
plt.figure(figsize=(7,4))
plt.scatter(x,y,
            color="#F546A3",
            alpha=0.6,
            label='Data Points')

#line plot
plt.plot(x, line,
         color="#000000",
         label=f'Regression line (r = {r_value:.3f})')

plt.title('NO2 vs. Humidity Correlation')
plt.ylabel('Relative Humidity (%)')
plt.xlabel('NO2 (ug/cu.m)')
plt.legend()
plt.show()

# %%
#regression line
x = air['Temperature']
y = air['Relative_Humidity']
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
line = slope * x + intercept

#scatter plot
plt.figure(figsize=(7,4))
plt.scatter(x,y,
            color="#F546A3",
            alpha=0.6,
            label='Data Points')

#line plot
plt.plot(x, line,
         color="#000000",
         label=f'Regression line (r = {r_value:.3f})')

plt.title('Temperature vs. Humidity Correlation')
plt.ylabel('Relative Humidity (%)')
plt.xlabel('Temperature (C)')
plt.legend()
plt.show()
